# %%
import os; os.environ['TF_CPP_MIN_LOG_LEVEL']='3'; 
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn import metrics as skmetrics
import pickle
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from keras.utils.vis_utils import plot_model

# %% [markdown]
# # Load Dataset

# %%
train_filename='dataset_training.csv'
df=pd.read_csv(train_filename, nrows=12001, header=0,comment='#', na_values=[""])

# %%
# Data preparation
X = df.drop(['target'], axis = 1).values
y = df['target'].values

print("Input shape (X): {} --- Output shape (y): {}".format(X.shape, y.shape))
# Out:
# Input shape (X): (12000, 4) --- Output shape (y): (12000,)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.2, stratify=y)

print("Train sets shape: {} {}".format(X_train.shape, y_train.shape))
print("Train sets shape: {} {}".format(X_validation.shape, y_validation.shape))
# Out:
# Train sets shape: (9600, 4) (9600,)
# Train sets shape: (2400, 4) (2400,)

# %%
# Data preparation
#X_validation = df_test.drop(['target'], axis = 1).values
#y_validation = df_test['target'].values

#print("Input shape (X): {} --- Output shape (y): {}".format(X_validation.shape, y_validation.shape))

# %%
# Combine Data
X = np.concatenate((X_train, X_validation), axis=0)
Y = np.concatenate((y_train, y_validation), axis=0)
print(X.shape)
print(Y.shape)
# Out:
# (12000, 4)
# (12000,)

# %% [markdown]
# *Model definition and compile*

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Dense(120, activation = 'relu'),
        tf.keras.layers.Dense(100, activation = 'relu'),
        tf.keras.layers.Dense(80, activation = 'relu'),
        tf.keras.layers.Dense(40, activation = 'relu'),
        tf.keras.layers.Dense(20, activation = 'relu'),
        tf.keras.layers.Dense(3, activation = 'softmax')
])

model.compile(loss= tf.keras.losses.sparse_categorical_crossentropy,
              optimizer = tf.keras.optimizers.Adam(lr = 0.01),
              metrics = ['accuracy'])
# Out:
# c:\Users\madda\Desktop\GUI\venv_new\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Build Starting Network

# %%
history=model.fit(X_train, y_train, epochs = 30, batch_size=150, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/30
# 64/64 [==============================] - 1s 8ms/step - loss: 83.3969 - accuracy: 0.3423 - val_loss: 1.1545 - val_accuracy: 0.3646
# Epoch 2/30
# 64/64 [==============================] - 0s 4ms/step - loss: 1.3637 - accuracy: 0.4062 - val_loss: 0.9968 - val_accuracy: 0.5688
# Epoch 3/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.9388 - accuracy: 0.5575 - val_loss: 0.9046 - val_accuracy: 0.5550
# Epoch 4/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.9017 - accuracy: 0.5791 - val_loss: 0.8454 - val_accuracy: 0.6592
# Epoch 5/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.8112 - accuracy: 0.6933 - val_loss: 0.7887 - val_accuracy: 0.6729
# Epoch 6/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.7628 - accuracy: 0.7127 - val_loss: 0.7176 - val_accuracy: 0.7629
# Epoch 7/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.7193 - accuracy: 0.7520 - val_loss: 0.7074 - val_accuracy: 0.6621
# Epoch 8/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.6680 - accuracy: 0.7895 - val_loss: 0.7245 - val_accuracy: 0.6675
# Epoch 9/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.7172 - val_loss: 0.5947 - val_accuracy: 0.8700
# Epoch 10/30
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5876 - accuracy: 0.8397 - val_loss: 0.5699 - val_accuracy: 0.7667
# Epoch 11/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.5613 - accuracy: 0.8208 - val_loss: 0.5691 - val_accuracy: 0.7308
# Epoch 12/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.5255 - accuracy: 0.8424 - val_loss: 0.4892 - val_accuracy: 0.9396
# Epoch 13/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.5025 - accuracy: 0.8415 - val_loss: 0.4649 - val_accuracy: 0.8296
# Epoch 14/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4619 - accuracy: 0.8621 - val_loss: 0.4389 - val_accuracy: 0.8579
# Epoch 15/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4450 - accuracy: 0.8722 - val_loss: 0.4367 - val_accuracy: 0.8050
# Epoch 16/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4483 - accuracy: 0.8545 - val_loss: 0.4304 - val_accuracy: 0.8467
# Epoch 17/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3887 - accuracy: 0.9151 - val_loss: 0.3751 - val_accuracy: 0.9471
# Epoch 18/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3951 - accuracy: 0.8789 - val_loss: 0.3862 - val_accuracy: 0.8571
# Epoch 19/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4784 - accuracy: 0.8227 - val_loss: 0.3915 - val_accuracy: 0.9133
# Epoch 20/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3790 - accuracy: 0.9182 - val_loss: 0.3519 - val_accuracy: 0.9596
# Epoch 21/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3506 - accuracy: 0.9298 - val_loss: 0.3323 - val_accuracy: 0.9571
# Epoch 22/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3439 - accuracy: 0.9195 - val_loss: 0.3188 - val_accuracy: 0.9588
# Epoch 23/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3340 - accuracy: 0.9197 - val_loss: 0.3137 - val_accuracy: 0.9367
# Epoch 24/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3113 - accuracy: 0.9380 - val_loss: 0.3108 - val_accuracy: 0.9100
# Epoch 25/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3168 - accuracy: 0.9151 - val_loss: 0.2962 - val_accuracy: 0.9663
# Epoch 26/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3163 - accuracy: 0.9162 - val_loss: 0.2907 - val_accuracy: 0.9192
# Epoch 27/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3013 - accuracy: 0.9231 - val_loss: 0.3098 - val_accuracy: 0.9154
# Epoch 28/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2827 - accuracy: 0.9371 - val_loss: 0.3000 - val_accuracy: 0.9400
# Epoch 29/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2720 - accuracy: 0.9371 - val_loss: 0.2874 - val_accuracy: 0.8983
# Epoch 30/30
# 64/64 [==============================] - 0s 4ms/step - loss: 0.2755 - accuracy: 0.9352 - val_loss: 0.2895 - val_accuracy: 0.9079

# %%
epochs = range(1, 31)

plt.plot(epochs, history.history['accuracy'], 'bo', label='Training acc')
plt.plot(epochs, history.history['val_accuracy'], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, history.history['loss'], 'bo', label='Training loss')
plt.plot(epochs, history.history['val_loss'], 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
